# %% [markdown]
# # QC Rainfall Observation Data

# %% [markdown]
# Made by Happy Trianna

# %% [markdown]
# ### Objective :
# - To do QC with the existed rainfall data from ground station
# - To check and handle the outlier of the data
# - To analyze the trend of all the station's data
# - To analyze the stability mean, variance, and independence of the data

# %% [markdown]
# ### Data
# The data that we use is rainfall from ground station from the existed station in BBWS Pemali Juana.

# %% [markdown]
# ### Import Libraries

# %%
import pandas as pd
import glob
import numpy as np
import seaborn as sns
from statsmodels.tsa.seasonal import seasonal_decompose
import pylab
import matplotlib.pyplot as plt
from statsmodels.tsa.seasonal import STL

# %% [markdown]
# ### Data Loading

# %%
# list all the rainfall station data
list_st=glob.glob('D:\\Happy\\RTOW\\Pemali Juana\\koreksi gpm\\CH koreksi\\Dipakai\\utk koreksi fix\\*.xls')
list_st[0][74:-4]
# Out:
# 'B-R.4b-Greneng'

# %%
# load the dataset
dataset=pd.read_excel("D:/Happy/koreksi_satelit/satellite_correction/uji_data_hujan_obs/PCH_bilibili/PCH_B_2010_2021.xlsx")
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4383 entries, 0 to 4382
# Data columns (total 11 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   TANGGAL                     4383 non-null   datetime64[ns]
#  1   PCH STASIUN BILI-BILI       4367 non-null   float64
#  2   PCH STASIUN KAMPILI         3539 non-null   float64
#  3   PCH STASIUN KD1             4305 non-null   float64
#  4   PCH STASIUN LENGKESE        3424 non-null   float64
#  5   PCH STASIUN LIMBUNGA        4325 non-null   float64
#  6   PCH STASIUN MACINI SOMBALA  2659 non-null   float64
#  7   PCH STASIUN MALINO          4338 non-null   float64
#  8   PCH STASIUN MANGEMPANG      3848 non-null   float64
#  9   PCH STASIUN PANAIKANG       3979 non-null   float64
#  10  PCH STASIUN POS1            3953 non-null   float64
# dtypes: datetime64[ns](1), float64(10)
# memory usage: 376.8 KB

# %% [markdown]
# We have 10 existed stations.

# %%
# preview the dataset
dataset.head()
# Out:
#      TANGGAL  PCH STASIUN BILI-BILI  PCH STASIUN KAMPILI  PCH STASIUN KD1  \
# 0 2010-01-01                    0.0                  0.0              0.0
# 1 2010-01-02                    5.0                  0.0              4.0
# 2 2010-01-03                    2.0                  0.0              0.0
# 3 2010-01-04                    8.0                 24.0             18.0
# 4 2010-01-05                    7.0                 59.0             30.0
#
#    PCH STASIUN LENGKESE  PCH STASIUN LIMBUNGA  PCH STASIUN MACINI SOMBALA  \
# 0                   NaN                   0.0                         0.0
# 1                   NaN                   1.0                         0.0
# 2                   NaN                   3.0                         0.0
# 3                   NaN                   8.0                         9.0
# 4                   NaN                  21.0                        45.0
#
#    PCH STASIUN MALINO  PCH STASIUN MANGEMPANG  PCH STASIUN PANAIKANG  \
# 0                 6.0                     0.0                    NaN
# 1                48.0                    22.0                    NaN
# 2                 1.0                     7.0                    NaN
# 3                 4.0                     9.0                    NaN
# 4                54.0                     4.0                    NaN
#
#    PCH STASIUN POS1
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN

# %% [markdown]
# Now we have all the data in numerical format.\
# Next, we will change the index into datetime index.

# %% [markdown]
# ### Exploratory Data Analysis

# %%
df=dataset.set_index('TANGGAL')
df
# Out:
#             PCH STASIUN BILI-BILI  PCH STASIUN KAMPILI  PCH STASIUN KD1  \
# TANGGAL
# 2010-01-01                    0.0                  0.0              0.0
# 2010-01-02                    5.0                  0.0              4.0
# 2010-01-03                    2.0                  0.0              0.0
# 2010-01-04                    8.0                 24.0             18.0
# 2010-01-05                    7.0                 59.0             30.0
# ...                           ...                  ...              ...
# 2021-12-27                    0.0                  NaN              6.0
# 2021-12-28                    1.0                  NaN             20.0
# 2021-12-29                    0.0                  NaN             10.0
# 2021-12-30                    0.0                  NaN             24.0
# 2021-12-31                    0.0                  NaN              8.0
#
#             PCH STASIUN LENGKESE  PCH STASIUN LIMBUNGA  \
# TANGGAL
# 2010-01-01                   NaN                   0.0
# 2010-01-02                   NaN                   1.0
# 2010-01-03                   NaN                   3.0
# 2010-01-04                   NaN                   8.0
# 2010-01-05                   NaN                  21.0
# ...                          ...                   ...
# 2021-12-27                   NaN                   1.0
# 2021-12-28                   NaN                  29.0
# 2021-12-29                   NaN                   7.0
# 2021-12-30                   NaN                  28.0
# 2021-12-31                   NaN                  17.0
#
#             PCH STASIUN MACINI SOMBALA  PCH STASIUN MALINO  \
# TANGGAL
# 2010-01-01                         0.0                 6.0
# 2010-01-02                         0.0                48.0
# 2010-01-03                         0.0                 1.0
# 2010-01-04                         9.0                 4.0
# 2010-01-05                        45.0                54.0
# ...                                ...                 ...
# 2021-12-27                         NaN                 0.0
# 2021-12-28                         NaN                 0.0
# 2021-12-29                         NaN                 0.0
# 2021-12-30                         NaN                 0.0
# 2021-12-31                         NaN                 0.0
#
#             PCH STASIUN MANGEMPANG  PCH STASIUN PANAIKANG  PCH STASIUN POS1
# TANGGAL
# 2010-01-01                     0.0                    NaN               NaN
# 2010-01-02                    22.0                    NaN               NaN
# 2010-01-03                     7.0                    NaN               NaN
# 2010-01-04                     9.0                    NaN               NaN
# 2010-01-05                     4.0                    NaN               NaN
# ...                            ...                    ...               ...
# 2021-12-27                     0.0                    4.0               5.0
# 2021-12-28                    32.0                   29.0              32.0
# 2021-12-29                     5.0                    6.0               6.0
# 2021-12-30                    28.0                   18.0              14.0
# 2021-12-31                    15.0                   27.0              19.0
#
# [4383 rows x 10 columns]

# %% [markdown]
# ### Independence Test

# %% [markdown]
# We try to use Pearman's correlation in order to find dependencies for each station.

# %%
#Check the correlations
corr = df.corr()
mask = np.triu(np.ones_like(corr, dtype=bool))
f, ax = plt.subplots(figsize=(8,8))
sns.heatmap(corr, annot=True, mask=mask)
plt.show()

# %% [markdown]
# There is no dependencies for each station. Except for `PCH STASIUN LENGKESE` VERSUS `PCH STASIUN POS 1`.

# %% [markdown]
# ### Trend Test

# %%
# Decomposing the time series

stl = STL(df['G-SE.201-Pengkol'], seasonal=11)
res = stl.fit()
fig = res.plot()

# %% [markdown]
# ### Outlier Test

# %%
# Function to find upper and lower boundaries for skewed distributed variables
# Let's calculate the boundaries outside which sit the outliers for skewed distributions
# Distance passed as an argument, gives us the option to estimate 1.5 times or 3 times the IQR to calculate the boundaries.
import matplotlib.pyplot as plt
import seaborn as sns


def find_skewed_boundaries(df, variable, distance,skew):
    
    if ((skew>=0.5) | (skew<=-0.5)):
    
        IQR = df[variable].quantile(0.75) - df[variable].quantile(0.25)

        lower_boundary = df[variable].quantile(0.25) - (IQR * distance)
        upper_boundary = df[variable].quantile(0.75) + (IQR * distance)
        
    else:
        lower_boundary=df[variable].mean() - (df[variable].std()*3)
        upper_boundary=df[variable].mean() + (df[variable].std()*3)
        
    return upper_boundary, lower_boundary

# Function to create histogram and boxplot.
# This functions takes a dataframe (df) and the variable of interest as arguments.

def diagnostic_plots(df, variable):
    # Define figure size
    plt.figure(figsize=(16, 4))

    # Histogram
    plt.subplot(1, 2, 1)
    sns.histplot(df[variable], bins=30, kde=True)
    plt.title('Histogram')

    # Boxplot
    plt.subplot(1, 2, 2)
    sns.boxplot(y=df[variable])
    plt.title('Boxplot')

    plt.show()

# %%
# Check the outlier in train data
for i in df.columns.values:
    globals()['Upper_'+i], globals()['Lower_'+i]=find_skewed_boundaries(df, i, 1.5,
                                                                                     df[i].skew())
    upper=globals()['Upper_'+i]
    lower=globals()['Lower_'+i]
    
    out_u=(len(df[df[i] > upper])/len(df) * 100)
    out_l=(len(df[df[i] < lower])/len(df) * 100)
    
    print(i)
    print('% Upper Outlier for '+i+' : {:.2f}%'.format(out_u))
    print('% Lower Outlier for '+i+' : {:.2f}%'.format(out_l))
    print('Skewness of '+i+' : {:.2f}%'.format(df[i].skew()))
    diagnostic_plots(df, i)
# Out:
# G-SE.201-Pengkol
# % Upper Outlier for G-SE.201-Pengkol : 23.51%
# % Lower Outlier for G-SE.201-Pengkol : 0.00%
# Skewness of G-SE.201-Pengkol : 4.86%
# G-SE.205b-Semen
# % Upper Outlier for G-SE.205b-Semen : 20.18%
# % Lower Outlier for G-SE.205b-Semen : 0.00%
# Skewness of G-SE.205b-Semen : 4.11%
# B-R.23-Jiken
# % Upper Outlier for B-R.23-Jiken : 8.24%
# % Lower Outlier for B-R.23-Jiken : 0.00%
# Skewness of B-R.23-Jiken : 4.00%
# D-SE.165-Karanganyar
# % Upper Outlier for D-SE.165-Karanganyar : 15.96%
# % Lower Outlier for D-SE.165-Karanganyar : 0.00%
# Skewness of D-SE.165-Karanganyar : 4.02%
# D-SE.166-Ngemplik
# % Upper Outlier for D-SE.166-Ngemplik : 19.52%
# % Lower Outlier for D-SE.166-Ngemplik : 0.00%
# Skewness of D-SE.166-Ngemplik : 5.93%
# D-SE.113a-Jatirogo
# % Upper Outlier for D-SE.113a-Jatirogo : 16.37%
# % Lower Outlier for D-SE.113a-Jatirogo : 0.00%
# Skewness of D-SE.113a-Jatirogo : 4.05%
# K-SE.156-Rahtawu
# % Upper Outlier for K-SE.156-Rahtawu : 15.80%
# % Lower Outlier for K-SE.156-Rahtawu : 0.00%
# Skewness of K-SE.156-Rahtawu : 5.22%
# P-SE.175-Trangkil
# % Upper Outlier for P-SE.175-Trangkil : 23.38%
# % Lower Outlier for P-SE.175-Trangkil : 0.00%
# Skewness of P-SE.175-Trangkil : 4.15%
# D-SE.104-Brambang
# % Upper Outlier for D-SE.104-Brambang : 0.00%
# % Lower Outlier for D-SE.104-Brambang : 0.00%
# Skewness of D-SE.104-Brambang : 0.00%
# C:\Users\admin\anaconda3\lib\site-packages\seaborn\distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# D-SE.96-Brumbung
# % Upper Outlier for D-SE.96-Brumbung : 14.73%
# % Lower Outlier for D-SE.96-Brumbung : 0.00%
# Skewness of D-SE.96-Brumbung : 3.53%
# G-SE.204-Nglejok
# % Upper Outlier for G-SE.204-Nglejok : 17.77%
# % Lower Outlier for G-SE.204-Nglejok : 0.00%
# Skewness of G-SE.204-Nglejok : 4.45%
# G-SE.197-Tanggungharjo
# % Upper Outlier for G-SE.197-Tanggungharjo : 0.00%
# % Lower Outlier for G-SE.197-Tanggungharjo : 0.00%
# Skewness of G-SE.197-Tanggungharjo : 0.00%
# C:\Users\admin\anaconda3\lib\site-packages\seaborn\distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# G-SE.105-Tegowanu GBG
# % Upper Outlier for G-SE.105-Tegowanu GBG : 0.00%
# % Lower Outlier for G-SE.105-Tegowanu GBG : 0.00%
# Skewness of G-SE.105-Tegowanu GBG : 0.00%
# C:\Users\admin\anaconda3\lib\site-packages\seaborn\distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# G-SE.196-Brati
# % Upper Outlier for G-SE.196-Brati : 0.08%
# % Lower Outlier for G-SE.196-Brati : 0.00%
# Skewness of G-SE.196-Brati : 7.27%
# G-SE.199-Gending
# % Upper Outlier for G-SE.199-Gending : 19.33%
# % Lower Outlier for G-SE.199-Gending : 0.00%
# Skewness of G-SE.199-Gending : 7.49%
# D-SE.132-Merak
# % Upper Outlier for D-SE.132-Merak : 13.99%
# % Lower Outlier for D-SE.132-Merak : 0.00%
# Skewness of D-SE.132-Merak : 3.95%
# D-SE.131-Panunggalan
# % Upper Outlier for D-SE.131-Panunggalan : 12.13%
# % Lower Outlier for D-SE.131-Panunggalan : 0.00%
# Skewness of D-SE.131-Panunggalan : 10.13%
# G-SE.133-Godong
# % Upper Outlier for G-SE.133-Godong : 24.34%
# % Lower Outlier for G-SE.133-Godong : 0.00%
# Skewness of G-SE.133-Godong : 15.04%
# G-SE.134-Gompeng
# % Upper Outlier for G-SE.134-Gompeng : 22.15%
# % Lower Outlier for G-SE.134-Gompeng : 0.00%
# Skewness of G-SE.134-Gompeng : 3.72%
# G-SE.187-Kramat
# % Upper Outlier for G-SE.187-Kramat : 21.22%
# % Lower Outlier for G-SE.187-Kramat : 0.00%
# Skewness of G-SE.187-Kramat : 3.51%
# G-SE.137-Wanutunggal
# % Upper Outlier for G-SE.137-Wanutunggal : 4.65%
# % Lower Outlier for G-SE.137-Wanutunggal : 0.00%
# Skewness of G-SE.137-Wanutunggal : 4.62%
# G-SE.217a-Butak
# % Upper Outlier for G-SE.217a-Butak : 18.40%
# % Lower Outlier for G-SE.217a-Butak : 0.00%
# Skewness of G-SE.217a-Butak : 4.34%
# B-R.7-Ngawen
# % Upper Outlier for B-R.7-Ngawen : 4.27%
# % Lower Outlier for B-R.7-Ngawen : 0.00%
# Skewness of B-R.7-Ngawen : 2.71%
# SE.9 Kunduran
# % Upper Outlier for SE.9 Kunduran : 0.00%
# % Lower Outlier for SE.9 Kunduran : 0.00%
# Skewness of SE.9 Kunduran : nan%
# C:\Users\admin\anaconda3\lib\site-packages\seaborn\distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# RD 24 Bogorejo
# % Upper Outlier for RD 24 Bogorejo : 8.10%
# % Lower Outlier for RD 24 Bogorejo : 0.00%
# Skewness of RD 24 Bogorejo : 4.97%
# B-R.6-Blora Kedung Jenar
# % Upper Outlier for B-R.6-Blora Kedung Jenar : 1.81%
# % Lower Outlier for B-R.6-Blora Kedung Jenar : 0.00%
# Skewness of B-R.6-Blora Kedung Jenar : 3.73%
# B-0-Gabus
# % Upper Outlier for B-0-Gabus : 7.45%
# % Lower Outlier for B-0-Gabus : 0.00%
# Skewness of B-0-Gabus : 4.35%
# B-R.4b-Greneng
# % Upper Outlier for B-R.4b-Greneng : 24.97%
# % Lower Outlier for B-R.4b-Greneng : 0.00%
# Skewness of B-R.4b-Greneng : 5.25%
# B-R.26-Japah
# % Upper Outlier for B-R.26-Japah : 6.49%
# % Lower Outlier for B-R.26-Japah : 0.00%
# Skewness of B-R.26-Japah : 3.74%
# P-SE.191a-Cabean
# % Upper Outlier for P-SE.191a-Cabean : 23.79%
# % Lower Outlier for P-SE.191a-Cabean : 0.00%
# Skewness of P-SE.191a-Cabean : 3.28%
# K-SE.129-Beru Genjang
# % Upper Outlier for K-SE.129-Beru Genjang : 23.65%
# % Lower Outlier for K-SE.129-Beru Genjang : 0.00%
# Skewness of K-SE.129-Beru Genjang : 3.85%
# D-SE.123-Bakung
# % Upper Outlier for D-SE.123-Bakung : 24.39%
# % Lower Outlier for D-SE.123-Bakung : 0.00%
# Skewness of D-SE.123-Bakung : 4.45%
# D-SE.118-Gajah
# % Upper Outlier for D-SE.118-Gajah : 18.89%
# % Lower Outlier for D-SE.118-Gajah : 0.00%
# Skewness of D-SE.118-Gajah : 4.78%
# D-SE.125-Wilalung
# % Upper Outlier for D-SE.125-Wilalung : 13.80%
# % Lower Outlier for D-SE.125-Wilalung : 0.00%
# Skewness of D-SE.125-Wilalung : 3.94%
# D-SE.119-Jatisono
# % Upper Outlier for D-SE.119-Jatisono : 22.72%
# % Lower Outlier for D-SE.119-Jatisono : 0.00%
# Skewness of D-SE.119-Jatisono : 3.56%
# D-SE.127-Grunggungan
# % Upper Outlier for D-SE.127-Grunggungan : 0.00%
# % Lower Outlier for D-SE.127-Grunggungan : 0.00%
# Skewness of D-SE.127-Grunggungan : nan%
# C:\Users\admin\anaconda3\lib\site-packages\seaborn\distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# D-SE.120-Dempet
# % Upper Outlier for D-SE.120-Dempet : 19.90%
# % Lower Outlier for D-SE.120-Dempet : 0.00%
# Skewness of D-SE.120-Dempet : 3.68%
# D-SE.112-Jali
# % Upper Outlier for D-SE.112-Jali : 0.00%
# % Lower Outlier for D-SE.112-Jali : 0.00%
# Skewness of D-SE.112-Jali : nan%
# C:\Users\admin\anaconda3\lib\site-packages\seaborn\distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# D-SE.114-Jebor
# % Upper Outlier for D-SE.114-Jebor : 0.00%
# % Lower Outlier for D-SE.114-Jebor : 0.00%
# Skewness of D-SE.114-Jebor : 0.00%
# C:\Users\admin\anaconda3\lib\site-packages\seaborn\distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# D-SE.121-Leles
# % Upper Outlier for D-SE.121-Leles : 15.11%
# % Lower Outlier for D-SE.121-Leles : 0.00%
# Skewness of D-SE.121-Leles : 3.17%
# D-SE.117-Buyaran Karangsari
# % Upper Outlier for D-SE.117-Buyaran Karangsari : 18.75%
# % Lower Outlier for D-SE.117-Buyaran Karangsari : 0.00%
# Skewness of D-SE.117-Buyaran Karangsari : 3.55%
# D-SE.124-Guntur
# % Upper Outlier for D-SE.124-Guntur : 19.98%
# % Lower Outlier for D-SE.124-Guntur : 0.00%
# Skewness of D-SE.124-Guntur : 3.91%
# D-SE.93-Purwosari
# % Upper Outlier for D-SE.93-Purwosari : 0.55%
# % Lower Outlier for D-SE.93-Purwosari : 0.00%
# Skewness of D-SE.93-Purwosari : 3.25%
# J-SE.143-Bapangan Jepara
# % Upper Outlier for J-SE.143-Bapangan Jepara : 18.12%
# % Lower Outlier for J-SE.143-Bapangan Jepara : 0.00%
# Skewness of J-SE.143-Bapangan Jepara : 4.40%
# J-SE.106-Kedung
# % Upper Outlier for J-SE.106-Kedung : 15.11%
# % Lower Outlier for J-SE.106-Kedung : 0.00%
# Skewness of J-SE.106-Kedung : 3.91%
# D-SE.110-Bungo
# % Upper Outlier for D-SE.110-Bungo : 20.83%
# % Lower Outlier for D-SE.110-Bungo : 0.00%
# Skewness of D-SE.110-Bungo : 3.81%
# K-SE.157-Karanggayam
# % Upper Outlier for K-SE.157-Karanggayam : 16.62%
# % Lower Outlier for K-SE.157-Karanggayam : 0.00%
# Skewness of K-SE.157-Karanggayam : 5.03%
# K-SE.158-Besito Kr.malang
# % Upper Outlier for K-SE.158-Besito Kr.malang : 15.22%
# % Lower Outlier for K-SE.158-Besito Kr.malang : 0.00%
# Skewness of K-SE.158-Besito Kr.malang : 6.27%
# J-SE.161-Pancur
# % Upper Outlier for J-SE.161-Pancur : 17.85%
# % Lower Outlier for J-SE.161-Pancur : 0.00%
# Skewness of J-SE.161-Pancur : 4.13%
# J-SE.150-Batealit
# % Upper Outlier for J-SE.150-Batealit : 17.25%
# % Lower Outlier for J-SE.150-Batealit : 0.00%
# Skewness of J-SE.150-Batealit : 7.40%
# 151 Mindahan
# % Upper Outlier for 151 Mindahan : 0.00%
# % Lower Outlier for 151 Mindahan : 0.00%
# Skewness of 151 Mindahan : nan%
# C:\Users\admin\anaconda3\lib\site-packages\seaborn\distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# D-SE.162 Bandaran-Mijen
# % Upper Outlier for D-SE.162 Bandaran-Mijen : 16.64%
# % Lower Outlier for D-SE.162 Bandaran-Mijen : 0.00%
# Skewness of D-SE.162 Bandaran-Mijen : 3.65%
# J-SE.160-Pelemkerep
# % Upper Outlier for J-SE.160-Pelemkerep : 24.39%
# % Lower Outlier for J-SE.160-Pelemkerep : 0.00%
# Skewness of J-SE.160-Pelemkerep : 5.71%
# J-SE.160-Jatisari
# % Upper Outlier for J-SE.160-Jatisari : 24.23%
# % Lower Outlier for J-SE.160-Jatisari : 0.00%
# Skewness of J-SE.160-Jatisari : 4.92%
# P-SE.178-Juana
# % Upper Outlier for P-SE.178-Juana : 21.87%
# % Lower Outlier for P-SE.178-Juana : 0.00%
# Skewness of P-SE.178-Juana : 3.95%
# P-SE.184 Pati
# % Upper Outlier for P-SE.184 Pati : 18.64%
# % Lower Outlier for P-SE.184 Pati : 0.00%
# Skewness of P-SE.184 Pati : 4.82%
# P-SE.181a-Gunung Rowo
# % Upper Outlier for P-SE.181a-Gunung Rowo : 19.68%
# % Lower Outlier for P-SE.181a-Gunung Rowo : 0.00%
# Skewness of P-SE.181a-Gunung Rowo : 4.97%
# P-SE.180a-Brambang pati
# % Upper Outlier for P-SE.180a-Brambang pati : 24.77%
# % Lower Outlier for P-SE.180a-Brambang pati : 0.00%
# Skewness of P-SE.180a-Brambang pati : 4.22%
# K-SE.186-Tanjungrejo
# % Upper Outlier for K-SE.186-Tanjungrejo : 16.51%
# % Lower Outlier for K-SE.186-Tanjungrejo : 0.00%
# Skewness of K-SE.186-Tanjungrejo : 5.03%
# P-SE.183-Langse
# % Upper Outlier for P-SE.183-Langse : 17.44%
# % Lower Outlier for P-SE.183-Langse : 0.00%
# Skewness of P-SE.183-Langse : 4.92%

# %% [markdown]
# There are bunch of stations contain the outliers, now we will check what kind of outlier the stations have. For natural outlier, we can leave the data as it is, but for unnatural outlier, we will check the data correctness first and change the unnatural outlier into nan or leave as it is.

# %% [markdown]
# ### Split the dataset into 3 datasets to analyze the stability mean and variance

# %%
# create the dataframe
df=pd.DataFrame({"date":pd.date_range(start="2011-01-01",end="2020-12-31")})
df.head()
# Out:
#         date
# 0 2011-01-01
# 1 2011-01-02
# 2 2011-01-03
# 3 2011-01-04
# 4 2011-01-05

# %% [markdown]
# We will use mass curve method to analyze the stability mean and variance of the dataset. *__Why use this method? Under the research of paper.__*

# %%
# append station name
for i in list_st:
    df[i[74:-4]]=dataset.loc[:,i[74:-4]]

# replacing the "-" character with nan value
df=df.replace('-', np.nan)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3653 entries, 0 to 3652
# Data columns (total 39 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   date                         3653 non-null   datetime64[ns]
#  1   B-R.4b-Greneng               3653 non-null   int64
#  2   D-SE.110-Bungo               3652 non-null   float64
#  3   D-SE.117-Buyaran Karangsari  3653 non-null   int64
#  4   D-SE.118-Gajah               3652 non-null   float64
#  5   D-SE.119-Jatisono            3652 non-null   float64
#  6   D-SE.120-Dempet              3652 non-null   float64
#  7   D-SE.123-Bakung              3644 non-null   float64
#  8   D-SE.124-Guntur              3653 non-null   int64
#  9   D-SE.131-Panunggalan         3653 non-null   int64
#  10  D-SE.132-Merak               3651 non-null   float64
#  11  D-SE.162 Bandaran-Mijen      3652 non-null   float64
#  12  D-SE.165-Karanganyar         3653 non-null   int64
#  13  D-SE.166-Ngemplik            3653 non-null   int64
#  14  D-SE.96-Brumbung             3652 non-null   float64
#  15  G-SE.133-Godong              3653 non-null   int64
#  16  G-SE.134-Gompeng             3646 non-null   float64
#  17  G-SE.187-Kramat              3652 non-null   float64
#  18  G-SE.199-Gending             3653 non-null   int64
#  19  G-SE.201-Pengkol             3653 non-null   int64
#  20  G-SE.205b-Semen              3653 non-null   int64
#  21  G-SE.217a-Butak              3653 non-null   int64
#  22  J-SE.106-Kedung              3653 non-null   float64
#  23  J-SE.143-Bapangan Jepara     3653 non-null   int64
#  24  J-SE.160-Jatisari            3653 non-null   int64
#  25  J-SE.160-Pelemkerep          3653 non-null   int64
#  26  J-SE.161-Pancur              3653 non-null   object
#  27  K-SE.129-Beru Genjang        3653 non-null   int64
#  28  K-SE.156-Rahtawu             3651 non-null   float64
#  29  K-SE.157-Karanggayam         3652 non-null   float64
#  30  K-SE.158-Besito Kr.malang    3653 non-null   int64
#  31  K-SE.186-Tanjungrejo         3653 non-null   int64
#  32  P-SE.175-Trangkil            3652 non-null   float64
#  33  P-SE.178-Juana               3653 non-null   int64
#  34  P-SE.180a-Brambang pati      3653 non-null   int64
#  35  P-SE.181a-Gunung Rowo        3653 non-null   int64
#  36  P-SE.183-Langse              3653 non-null   int64
#  37  P-SE.184 Pati                3653 non-null   int64
#  38  P-SE.191a-Cabean             3653 non-null   int64
# dtypes: datetime64[ns](1), float64(14), int64(23), object(1)
# memory usage: 1.1+ MB

# %%
df.loc[:,"J-SE.161-Pancur"]=df.loc[:,"J-SE.161-Pancur"].replace('7`',7)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3653 entries, 0 to 3652
# Data columns (total 39 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   date                         3653 non-null   datetime64[ns]
#  1   B-R.4b-Greneng               3653 non-null   int64
#  2   D-SE.110-Bungo               3652 non-null   float64
#  3   D-SE.117-Buyaran Karangsari  3653 non-null   int64
#  4   D-SE.118-Gajah               3652 non-null   float64
#  5   D-SE.119-Jatisono            3652 non-null   float64
#  6   D-SE.120-Dempet              3652 non-null   float64
#  7   D-SE.123-Bakung              3644 non-null   float64
#  8   D-SE.124-Guntur              3653 non-null   int64
#  9   D-SE.131-Panunggalan         3653 non-null   int64
#  10  D-SE.132-Merak               3651 non-null   float64
#  11  D-SE.162 Bandaran-Mijen      3652 non-null   float64
#  12  D-SE.165-Karanganyar         3653 non-null   int64
#  13  D-SE.166-Ngemplik            3653 non-null   int64
#  14  D-SE.96-Brumbung             3652 non-null   float64
#  15  G-SE.133-Godong              3653 non-null   int64
#  16  G-SE.134-Gompeng             3646 non-null   float64
#  17  G-SE.187-Kramat              3652 non-null   float64
#  18  G-SE.199-Gending             3653 non-null   int64
#  19  G-SE.201-Pengkol             3653 non-null   int64
#  20  G-SE.205b-Semen              3653 non-null   int64
#  21  G-SE.217a-Butak              3653 non-null   int64
#  22  J-SE.106-Kedung              3653 non-null   float64
#  23  J-SE.143-Bapangan Jepara     3653 non-null   int64
#  24  J-SE.160-Jatisari            3653 non-null   int64
#  25  J-SE.160-Pelemkerep          3653 non-null   int64
#  26  J-SE.161-Pancur              3653 non-null   int64
#  27  K-SE.129-Beru Genjang        3653 non-null   int64
#  28  K-SE.156-Rahtawu             3651 non-null   float64
#  29  K-SE.157-Karanggayam         3652 non-null   float64
#  30  K-SE.158-Besito Kr.malang    3653 non-null   int64
#  31  K-SE.186-Tanjungrejo         3653 non-null   int64
#  32  P-SE.175-Trangkil            3652 non-null   float64
#  33  P-SE.178-Juana               3653 non-null   int64
#  34  P-SE.180a-Brambang pati      3653 non-null   int64
#  35  P-SE.181a-Gunung Rowo        3653 non-null   int64
#  36  P-SE.183-Langse              3653 non-null   int64
#  37  P-SE.184 Pati                3653 non-null   int64
#  38  P-SE.191a-Cabean             3653 non-null   int64
# dtypes: datetime64[ns](1), float64(14), int64(24)
# memory usage: 1.1 MB

# %%
df2=df.copy()
for i in range (1,df2.shape[0]):
    df2.iloc[i,1:]=df2.iloc[i-1,1:]+df2.iloc[i,1:]
df2
# Out:
#            date  B-R.4b-Greneng  D-SE.110-Bungo  D-SE.117-Buyaran Karangsari  \
# 0    2011-01-01               3            13.0                            1
# 1    2011-01-02               6            29.0                           88
# 2    2011-01-03               6            58.0                           97
# 3    2011-01-04               6            61.0                          106
# 4    2011-01-05               6            68.0                          106
# ...         ...             ...             ...                          ...
# 3648 2020-12-27           13345             NaN                        20638
# 3649 2020-12-28           13367             NaN                        20638
# 3650 2020-12-29           13367             NaN                        20724
# 3651 2020-12-30           13367             NaN                        20725
# 3652 2020-12-31           13415             NaN                        20733
#
#       D-SE.118-Gajah  D-SE.119-Jatisono  D-SE.120-Dempet  D-SE.123-Bakung  \
# 0               11.0                7.0              7.0             65.0
# 1               24.0               51.0             89.0            122.0
# 2               31.0               74.0             99.0            122.0
# 3               32.0               74.0            111.0            135.0
# 4               32.0               85.0            136.0            135.0
# ...              ...                ...              ...              ...
# 3648             NaN                NaN              NaN              NaN
# 3649             NaN                NaN              NaN              NaN
# 3650             NaN                NaN              NaN              NaN
# 3651             NaN                NaN              NaN              NaN
# 3652             NaN                NaN              NaN              NaN
#
#       D-SE.124-Guntur  D-SE.131-Panunggalan  ...  K-SE.157-Karanggayam  \
# 0                   3                     5  ...                  37.0
# 1                  74                    12  ...                  45.0
# 2                  78                    20  ...                  58.0
# 3                  88                    25  ...                  81.0
# 4                  97                    33  ...                  81.0
# ...               ...                   ...  ...                   ...
# 3648            19863                  3861  ...                   NaN
# 3649            19863                  3865  ...                   NaN
# 3650            19910                  3871  ...                   NaN
# 3651            19918                  3876  ...                   NaN
# 3652            19925                  3884  ...                   NaN
#
#       K-SE.158-Besito Kr.malang  K-SE.186-Tanjungrejo  P-SE.175-Trangkil  \
# 0                            12                    32                0.0
# 1                            21                    45               16.0
# 2                            23                    51               16.0
# 3                            27                    63               16.0
# 4                            28                    63               16.0
# ...                         ...                   ...                ...
# 3648                      19438                 23933                NaN
# 3649                      19451                 23944                NaN
# 3650                      19451                 23944                NaN
# 3651                      19475                 23959                NaN
# 3652                      19492                 24000                NaN
#
#       P-SE.178-Juana  P-SE.180a-Brambang pati  P-SE.181a-Gunung Rowo  \
# 0                  0                       30                      0
# 1                 23                       30                      0
# 2                 23                       30                      0
# 3                 23                       30                      0
# 4                 23                       30                      0
# ...              ...                      ...                    ...
# 3648           12101                    19157                  18858
# 3649           12115                    19177                  18890
# 3650           12115                    19177                  18913
# 3651           12115                    19188                  18931
# 3652           12132                    19204                  18956
#
#       P-SE.183-Langse  P-SE.184 Pati  P-SE.191a-Cabean
# 0                  13              8                30
# 1                  16              8                30
# 2                  16              8                30
# 3                  16              8                30
# 4                  16              8                30
# ...               ...            ...               ...
# 3648            17046          15997             16218
# 3649            17046          15997             16218
# 3650            17046          15997             16218
# 3651            17046          15997             16218
# 3652            17046          15997             16218
#
# [3653 rows x 39 columns]

# %%
df
# Out:
#            date  B-R.4b-Greneng  D-SE.110-Bungo  D-SE.117-Buyaran Karangsari  \
# 0    2011-01-01               3            13.0                            1
# 1    2011-01-02               3            16.0                           87
# 2    2011-01-03               0            29.0                            9
# 3    2011-01-04               0             3.0                            9
# 4    2011-01-05               0             7.0                            0
# ...         ...             ...             ...                          ...
# 3648 2020-12-27               5             0.0                            0
# 3649 2020-12-28              22             8.0                            0
# 3650 2020-12-29               0             0.0                           86
# 3651 2020-12-30               0            14.0                            1
# 3652 2020-12-31              48            34.0                            8
#
#       D-SE.118-Gajah  D-SE.119-Jatisono  D-SE.120-Dempet  D-SE.123-Bakung  \
# 0               11.0                7.0              7.0             65.0
# 1               13.0               44.0             82.0             57.0
# 2                7.0               23.0             10.0              0.0
# 3                1.0                0.0             12.0             13.0
# 4                0.0               11.0             25.0              0.0
# ...              ...                ...              ...              ...
# 3648             0.0                0.0              0.0              0.0
# 3649             0.0                0.0              0.0              0.0
# 3650            25.0               58.0              0.0             19.0
# 3651             5.0                0.0              0.0              0.0
# 3652             0.0                8.0              0.0              0.0
#
#       D-SE.124-Guntur  D-SE.131-Panunggalan  ...  K-SE.157-Karanggayam  \
# 0                   3                     5  ...                  37.0
# 1                  71                     7  ...                   8.0
# 2                   4                     8  ...                  13.0
# 3                  10                     5  ...                  23.0
# 4                   9                     8  ...                   0.0
# ...               ...                   ...  ...                   ...
# 3648                0                     0  ...                   0.0
# 3649                0                     4  ...                  65.0
# 3650               47                     6  ...                   0.0
# 3651                8                     5  ...                  30.0
# 3652                7                     8  ...                  45.0
#
#       K-SE.158-Besito Kr.malang  K-SE.186-Tanjungrejo  P-SE.175-Trangkil  \
# 0                            12                    32                0.0
# 1                             9                    13               16.0
# 2                             2                     6                0.0
# 3                             4                    12                0.0
# 4                             1                     0                0.0
# ...                         ...                   ...                ...
# 3648                          0                    17               13.0
# 3649                         13                    11                6.0
# 3650                          0                     0                0.0
# 3651                         24                    15                0.0
# 3652                         17                    41               46.0
#
#       P-SE.178-Juana  P-SE.180a-Brambang pati  P-SE.181a-Gunung Rowo  \
# 0                  0                       30                      0
# 1                 23                        0                      0
# 2                  0                        0                      0
# 3                  0                        0                      0
# 4                  0                        0                      0
# ...              ...                      ...                    ...
# 3648               0                       37                     36
# 3649              14                       20                     32
# 3650               0                        0                     23
# 3651               0                       11                     18
# 3652              17                       16                     25
#
#       P-SE.183-Langse  P-SE.184 Pati  P-SE.191a-Cabean
# 0                  13              8                30
# 1                   3              0                 0
# 2                   0              0                 0
# 3                   0              0                 0
# 4                   0              0                 0
# ...               ...            ...               ...
# 3648                0              0                 0
# 3649                0              0                 0
# 3650                0              0                 0
# 3651                0              0                 0
# 3652                0              0                 0
#
# [3653 rows x 39 columns]

# %% [markdown]
# ### Mass Curve

# %%
df2.plot(x="date", y=df2.columns[1:10].values,
        kind="line", figsize=(8, 6))
df2.plot(x="date", y=df2.columns[10:20].values,
        kind="line", figsize=(8, 6))
df2.plot(x="date", y=df2.columns[20:38].values,
        kind="line", figsize=(8, 6))

# %%
import matplotlib.pyplot as plt

# %%
df3=df.copy()
df3=df3.drop(['D-SE.118-Gajah', 'D-SE.119-Jatisono','D-SE.120-Dempet','D-SE.123-Bakung','D-SE.131-Panunggalan',\
                'D-SE.162 Bandaran-Mijen','D-SE.96-Brumbung','G-SE.187-Kramat','K-SE.156-Rahtawu','K-SE.157-Karanggayam',\
               'P-SE.178-Juana','D-SE.132-Merak','G-SE.134-Gompeng'], axis=1)
df3[df3.loc[:,"G-SE.201-Pengkol"]>200]= 0
for i in range (1,df3.shape[1]):
    df3[df3.iloc[:,i]>250]=0
df3.to_excel("CH_obsQC.xlsx") 
df3
# Out:
#                      date  B-R.4b-Greneng  D-SE.110-Bungo  \
# 0     2011-01-01 00:00:00               3            13.0
# 1     2011-01-02 00:00:00               3            16.0
# 2     2011-01-03 00:00:00               0            29.0
# 3     2011-01-04 00:00:00               0             3.0
# 4     2011-01-05 00:00:00               0             7.0
# ...                   ...             ...             ...
# 3648  2020-12-27 00:00:00               5             0.0
# 3649  2020-12-28 00:00:00              22             8.0
# 3650  2020-12-29 00:00:00               0             0.0
# 3651  2020-12-30 00:00:00               0            14.0
# 3652  2020-12-31 00:00:00              48            34.0
#
#       D-SE.117-Buyaran Karangsari  D-SE.124-Guntur  D-SE.165-Karanganyar  \
# 0                               1                3                    23
# 1                              87               71                    29
# 2                               9                4                     9
# 3                               9               10                     6
# 4                               0                9                     1
# ...                           ...              ...                   ...
# 3648                            0                0                     1
# 3649                            0                0                     1
# 3650                           86               47                    23
# 3651                            1                8                     0
# 3652                            8                7                    42
#
#       D-SE.166-Ngemplik  G-SE.133-Godong  G-SE.199-Gending  G-SE.201-Pengkol  \
# 0                    29                0                12                12
# 1                    29               22                18                12
# 2                    16                6                 7                 3
# 3                     5                1                 4                 0
# 4                     0                8                19                 9
# ...                 ...              ...               ...               ...
# 3648                  0               30                 0                 0
# 3649                  0                0                 8                 5
# 3650                 18               28                14                12
# 3651                  4                0                 5                 4
# 3652                  7               15                34                33
#
#       ...  J-SE.161-Pancur  K-SE.129-Beru Genjang  K-SE.158-Besito Kr.malang  \
# 0     ...               22                      3                         12
# 1     ...                0                      0                          9
# 2     ...                0                      0                          2
# 3     ...                0                      0                          4
# 4     ...                0                     29                          1
# ...   ...              ...                    ...                        ...
# 3648  ...                0                      9                          0
# 3649  ...               43                      0                         13
# 3650  ...                0                      2                          0
# 3651  ...                3                      0                         24
# 3652  ...              122                      7                         17
#
#       K-SE.186-Tanjungrejo  P-SE.175-Trangkil  P-SE.180a-Brambang pati  \
# 0                       32                0.0                       30
# 1                       13               16.0                        0
# 2                        6                0.0                        0
# 3                       12                0.0                        0
# 4                        0                0.0                        0
# ...                    ...                ...                      ...
# 3648                    17               13.0                       37
# 3649                    11                6.0                       20
# 3650                     0                0.0                        0
# 3651                    15                0.0                       11
# 3652                    41               46.0                       16
#
#       P-SE.181a-Gunung Rowo  P-SE.183-Langse  P-SE.184 Pati  P-SE.191a-Cabean
# 0                         0               13              8                30
# 1                         0                3              0                 0
# 2                         0                0              0                 0
# 3                         0                0              0                 0
# 4                         0                0              0                 0
# ...                     ...              ...            ...               ...
# 3648                     36                0              0                 0
# 3649                     32                0              0                 0
# 3650                     23                0              0                 0
# 3651                     18                0              0                 0
# 3652                     25                0              0                 0
#
# [3653 rows x 26 columns]

# %%
plt.plot(df3.loc[:,"G-SE.201-Pengkol"])

# %%
df3.plot(x="date", y=df3.columns[1:].values,
        kind="line", figsize=(10, 8))
